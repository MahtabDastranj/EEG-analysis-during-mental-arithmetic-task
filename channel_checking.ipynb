# %%
# !pip install mne scipy pandas
# Out:
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
import mne, scipy
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_path = r"eeg-during-mental-arithmetic-tasks-1.0.0/Subject27_2.edf"
# Load the data
raw_data = mne.io.read_raw_edf(file_path, preload=True, verbose=False)

# Display basic information about the data
raw_data.info
# Out:
# <Info | 8 non-empty values
#  bads: []
#  ch_names: EEG Fp1, EEG Fp2, EEG F3, EEG F4, EEG F7, EEG F8, EEG T3, EEG ...
#  chs: 21 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: 2010-01-01 00:00:00 UTC
#  nchan: 21
#  projs: []
#  sfreq: 500.0 Hz
#  subject_info: 4 items (dict)
# >

# %%
# Plot raw EEG signals
raw_data.plot(n_channels=21, scalings='auto', title='Raw EEG Signals', show=True)

# Plot the power spectral density (PSD) of the raw signals
raw_data.plot_psd(fmax=128, show=True)

# Add a title to the PSD plot
plt.title('Power Spectral Density of Raw EEG Signals')
plt.show()
# Out:
# <MNEBrowseFigure size 800x800 with 4 Axes>
# NOTE: plot_psd() is a legacy function. New code should use .compute_psd().plot().
# Effective window size : 4.096 (s)
# Plotting power spectral density (dB=True).
# C:\Users\MDastranj\AppData\Local\Temp\ipykernel_12176\2293798279.py:5: FutureWarning: The value of `amplitude='auto'` will be removed in MNE 1.8.0, and the new default will be `amplitude=False`.
#   raw_data.plot_psd(fmax=128, show=True)
# C:\Users\MDastranj\AppData\Local\Temp\ipykernel_12176\2293798279.py:5: RuntimeWarning: Channel locations not available. Disabling spatial colors.
#   raw_data.plot_psd(fmax=128, show=True)
# E:\python\Lib\site-packages\mne\viz\utils.py:167: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   (fig or plt).show(**kwargs)
# <MNELineFigure size 1000x350 with 1 Axes>
